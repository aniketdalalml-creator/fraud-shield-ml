# %% [markdown]
# # Fraud Shield ML - Exploratory Data Analysis (EDA)
#
# This notebook is for investigation only. Do not place production code here.

# %%
import pandas as pd

from config import get_settings

cfg = get_settings()
print('Raw data path:', cfg.raw_data_path)
